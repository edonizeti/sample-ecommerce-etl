# %% [markdown]
# <a href="https://colab.research.google.com/github/edonizeti/Challenge-BI-Engineer/blob/main/Challenge_Data_Gathering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Detail Blog Post**: https://medium.com/@purba0101/how-to-clone-private-github-repo-in-google-colab-using-ssh-77384cfef18f

# %% [markdown]
# # Challenge Introduction

# %% [markdown]
# There are Five stages to this task:
#
# 1. **Data Gathering** : Unhash the data (/data/bi_data.zip),extract it and, more importantly, place it in a data warehouse like Snowflake or Big Query so you can use it for the rest of the tasks in this challenge.
#
# 2. **Data Cleaning** : Write SQL queries to answer the following questions using the data.
#
# > Can you identify some data quality issues within all the three sources that have been provided and cleaned before any further transformation or analysis is done?
#
# > Can you document the issues and assumptions made?
#
# 3. **Data Transformation** : Transform the raw data provided in order to create staging and summary tables as shown in the repo details.
#
# 4. **Data Analysis** : Analyse the Data - Based on the above tables created can you answer the following questions.
#
# > Which event has low transition rate and can you let us know the transition rate across each of the events?
#
# > What is the percentage of Cart abandonment across the store, where Cart abandonment consists of events_type (Added to cart and checkout started) but orders are not completed?
#
# > Find the average duration between checkout started and order completed and do you find any anomaly in the data?
#
# 5. **Data Visualisation** : Visualise the Data
#
# > Create a dashboard to visualise the data and provide us with at least 3 interesting insights that you can draw from this data
#
#
# Please have a look at this github repository for more detail.
#
# https://github.com/data-talks-sydney/Challenge-BI-Engineer

# %% [markdown]
# # Github repository cloning

# %% [markdown]
# ## **Step 1: Generate a new SSH key**

# %%
# !ssh-keygen -t rsa -b 4096
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:iNJ2pFUswG5FwfimsBzZu4x89gSE13kTk8wf31JX96A root@b71ed89c4f89
# The key's randomart image is:
# +---[RSA 4096]----+
# |   ..=o=+.    . +|
# |   .o.+o=o.  ...+|
# |  .+oo=.o. oEo ..|
# |  +++=oo .. o .  |
# | ..=*+o S    .   |
# |  oooo           |
# | . o ..          |
# |  o =.           |
# |   o ..          |
# +----[SHA256]-----+

# %% [markdown]
# ## **Step 2: Add SSH key fingerprints**

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-2ff5bbdf

# %% [markdown]
# ## **Step 3: Get the SSH key, copy it and add the key to Github following [this documentation ](https://docs.github.com/en/github/authenticating-to-github/adding-a-new-ssh-key-to-your-github-account)**

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... root@b71ed89c4f89

# %%
# !cat /root/.ssh/id_rsa

# %%
# !ls -ltr /root/.ssh/
# Out:
# total 12
# -rw-r--r-- 1 root root  743 Jun 29 03:53 id_rsa.pub
# -rw------- 1 root root 3381 Jun 29 03:53 id_rsa
# -rw-r--r-- 1 root root 1742 Jun 29 03:53 known_hosts

# %% [markdown]
# ## **Test SSH key**

# %%
# !ssh -T git@github.com
# Out:
# Warning: Permanently added the RSA host key for IP address '140.82.113.4' to the list of known hosts.
# Hi analves! You've successfully authenticated, but GitHub does not provide shell access.

# %% [markdown]
# ## **Step 4: Specify Git configuration settings**

# %%
# !git config --global user.email "antonio.gonzales@gmail.com"
# !git config --global user.name "aalves"

# %% [markdown]
# ## **Clone a private repository from Github**

# %%
# !git clone git@github.com:data-talks-sydney/Challenge-BI-Engineer.git
# Out:
# Cloning into 'Challenge-BI-Engineer'...
# Warning: Permanently added the RSA host key for IP address '140.82.114.4' to the list of known hosts.
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 83 (delta 30), reused 66 (delta 22), pack-reused 0
# Receiving objects: 100% (83/83), 7.80 MiB | 6.31 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %% [markdown]
# # Unzip the files

# %%
# !ls -ltr ./Challenge-BI-Engineer/*
# Out:
# -rw-r--r-- 1 root root 8103 Jun 29 03:56 ./Challenge-BI-Engineer/README.md
#
# ./Challenge-BI-Engineer/data:
# total 4004
# -rw-r--r-- 1 root root 4099254 Jun 29 03:56 bi_data.zip

# %%
# !unzip ./Challenge-BI-Engineer/data/bi_data.zip
# Out:
# Archive:  ./Challenge-BI-Engineer/data/bi_data.zip
#   inflating: interactions.csv
#   inflating: products.csv
#   inflating: users.csv

# %% [markdown]
# # Authentication

# %% [markdown]
# ## GCP

# %%
# !gcloud auth login
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=QSFBuiWIEUq2TcLBCFyu0JIywIB9OI&prompt=consent&access_type=offline&code_challenge=HoaFe_Qiv905wYLVfrsc5ob9OlkQW3OrFJFGUuNrcCk&code_challenge_method=S256
#
# Enter authorization code: 4/0AZEOvhVBJJdHfDcY6a7xPb45nDkXUwtAEJYVYI9oVKBllUwBAKXf4lviq78ZFE5Es-QoyA
#
# You are now logged in as [antonio.gonzales@gmail.com].
# Your current project is [None].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %% [markdown]
# ## BQ

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# # Loading files to BQ

# %% [markdown]
# ## Creating a "Data Talk" project

# %% [markdown]
# Please follow the steps here to create a project in BQ Sandbox
#
# https://cloud.google.com/bigquery/docs/sandbox

# %% [markdown]
# ## Creating source dataset

# %%
# !bq mk --project_id=data-talk-385706 sources
# Out:
# Dataset 'data-talk-385706:sources' successfully created.

# %% [markdown]
# ## Loading users table

# %%
# !head users.csv
# Out:
# id,username,email,first_name,last_name,addresses,age,gender,persona,discount_persona
# 1584,user1584,jo.davis@example.com,Jo,Davis,"[{'first_name': 'Jo', 'last_name': 'Davis', 'address1': '6763 Justin River Suite 929', 'address2': '', 'country': 'US', 'city': 'Jasonville', 'state': 'CA', 'zipcode': '91864', 'default': True}]",35,F,apparel_footwear_accessories,all_discounts
# 5753,user5753,amy.garcia@example.com,Amy,Garcia,"[{'first_name': 'Amy', 'last_name': 'Garcia', 'address1': '66174 Scott Haven', 'address2': '', 'country': 'US', 'city': 'Briannafurt', 'state': 'VA', 'zipcode': '24087', 'default': True}]",22,F,instruments_books_electronics,all_discounts
# 5819,user5819,amy.foster@example.com,Amy,Foster,"[{'first_name': 'Amy', 'last_name': 'Foster', 'address1': '556 Carol Vista Suite 468', 'address2': '', 'country': 'US', 'city': 'Port Christinemouth', 'state': 'OH', 'zipcode': '45011', 'default': True}]",55,F,books_apparel_homedecor,all_discounts
# 1988,user1988,amy.santiago@example.com,Amy,Santiago,"[{'first_name': 'Amy', 'last_name': 'Santiago', 'address1': '112 Le Rest', 'address2': '', 'country': 'US', 'city': 'New Nicole', 'state': 'OH', 'zipcode': '44904', 'default': True}]",35,F,apparel_footwear_accessories,all_discounts
# 5202,user5202,amy.strickland@example.com,Amy,Strickland,"[{'first_name': 'Amy', 'last_name': 'Strickland', 'address1': '7373 Jerry Well Suite 280', 'address2': '', 'country': 'US', 'city': 'Nataliebury', 'state': 'MT', 'zipcode': '59262', 'default': True}]",64,F,electronics_outdoors_footwear,all_discounts
# 405,user405,amy.smith@example.com,Amy,Smith,"[{'first_name': 'Amy', 'last_name': 'Smith', 'address1': '584 Joseph Walks', 'address2': '', 'country': 'US', 'city': 'Johnsonfurt', 'state': 'KS', 'zipcode': '67121', 'default': True}]",29,F,beauty_accessories_instruments,all_discounts
# 5025,user5025,amy.bailey@example.com,Amy,Bailey,"[{'first_name': 'Amy', 'last_name': 'Bailey', 'address1': '46266 Miller Throughway Apt. 114', 'address2': '', 'country': 'US', 'city': 'Karinaside', 'state': 'KS', 'zipcode': '66954', 'default': True}]",55,F,floral_beauty_jewelry,all_discounts
# 2393,user2393,amy.adams@example.com,Amy,Adams,"[{'first_name': 'Amy', 'last_name': 'Adams', 'address1': '3555 Case Forks', 'address2': '', 'country': 'US', 'city': 'Rachaelburgh', 'state': 'SC', 'zipcode': '29114', 'default': True}]",33,F,floral_beauty_jewelry,all_discounts
# 3885,user3885,amy.sanchez@example.com,Amy,Sanchez,"[{'first_name': 'Amy', 'last_name': 'Sanchez', 'address1': '17166 Williams Ports Apt. 886', 'address2': '', 'country': 'US', 'city': 'Port Josefort', 'state': 'MI', 'zipcode': '48196', 'default': True}]",51,F,books_apparel_homedecor,all_discounts

# %%
# !bq load --project_id=data-talk-385706 --skip_leading_rows=1 --source_format=CSV sources.users users.csv id:INTEGER,username:STRING,email:STRING,first_name:STRING,last_name:STRING,addresses:STRING,age:INTEGER,gender:STRING,persona:STRING,discount_persona:STRING
# Out:
# Upload complete.
# Waiting on bqjob_r47a438c743fd7e73_00000189055ce68f_1 ... (1s) Current status: DONE

# %%
# %%bigquery --project data-talk-385706
#
# select
#   *
# from data-talk-385706.sources.users
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      id  username                      email first_name last_name  \
# 0  5025  user5025     amy.bailey@example.com        Amy    Bailey
# 1  2393  user2393      amy.adams@example.com        Amy     Adams
# 2  2555  user2555       ana.rice@example.com        Ana      Rice
# 3   614   user614     ann.lawson@example.com        Ann    Lawson
# 4   962   user962  anna.santiago@example.com       Anna  Santiago
# 5  1762  user1762  beth.gonzalez@example.com       Beth  Gonzalez
# 6  3631  user3631      dawn.wood@example.com       Dawn      Wood
# 7  1472  user1472    erin.garcia@example.com       Erin    Garcia
# 8  5232  user5232    lisa.pierce@example.com       Lisa    Pierce
# 9  2020  user2020      mary.wood@example.com       Mary      Wood
#
#                                            addresses  age gender  \
# 0  [{'first_name': 'Amy', 'last_name': 'Bailey', ...   55      F
# 1  [{'first_name': 'Amy', 'last_name': 'Adams', '...   33      F
# 2  [{'first_name': 'Ana', 'last_name': 'Rice', 'a...   21      F
# 3  [{'first_name': 'Ann', 'last_name': 'Lawson', ...   21      F
# 4  [{'first_name': 'Anna', 'last_name': 'Santiago...   38      F
# 5  [{'first_name': 'Beth', 'last_name': 'Gonzalez...   49      F
# 6  [{'first_name': 'Dawn', 'last_name': 'Wood', '...   44      F
# 7  [{'first_name': 'Erin', 'last_name': 'Garcia',...   43      F
# 8  [{'first_name': 'Lisa', 'last_name': 'Pierce',...   32      F
# 9  [{'first_name': 'Mary', 'last_name': 'Wood', '...   40      F
#
#                  persona discount_persona
# 0  floral_beauty_jewelry    all_discounts
# 1  floral_beauty_jewelry    all_discounts
# 2  floral_beauty_jewelry    all_discounts
# 3  floral_beauty_jewelry    all_discounts
# 4  floral_beauty_jewelry    all_discounts
# 5  floral_beauty_jewelry    all_discounts
# 6  floral_beauty_jewelry    all_discounts
# 7  floral_beauty_jewelry    all_discounts
# 8  floral_beauty_jewelry    all_discounts
# 9  floral_beauty_jewelry    all_discounts

# %% [markdown]
# ## Loading products

# %%
# !head products.csv
# Out:
# id,url,name,category,style,description,price,image,gender_affinity,current_stock
# baae9ca1-2fd5-4161-8eb3-d0c0616e34f6,http://d3idkbp2p2okv.cloudfront.net/#/product/baae9ca1-2fd5-4161-8eb3-d0c0616e34f6,Pet Accessory,outdoors,pet,Your pet will love this accessory,-11.99,http://d3idkbp2p2okv.cloudfront.net/images/outdoors/baae9ca1-2fd5-4161-8eb3-d0c0616e34f6.jpg,,-9
# d51e4f8e-c010-4ddd-a88b-b70820806e17,http://d3idkbp2p2okv.cloudfront.net/#/product/d51e4f8e-c010-4ddd-a88b-b70820806e17,Dog Accessory,outdoors,pet,Your dog will love this accessory,-43.99,http://d3idkbp2p2okv.cloudfront.net/images/outdoors/d51e4f8e-c010-4ddd-a88b-b70820806e17.jpg,,-14
# 94e5c5a1-ee87-4d12-9657-e9ef9b27e901,http://d3idkbp2p2okv.cloudfront.net/#/product/94e5c5a1-ee87-4d12-9657-e9ef9b27e901,Upright Piano,instruments,keys,This upright piano will delight the most demanding musician,-407.99,http://d3idkbp2p2okv.cloudfront.net/images/instruments/94e5c5a1-ee87-4d12-9657-e9ef9b27e901.jpg,,-14
# f0501d3b-1bbb-44b1-905d-d11eb8a7fe01,http://d3idkbp2p2okv.cloudfront.net/#/product/f0501d3b-1bbb-44b1-905d-d11eb8a7fe01,Spare bookshelves,housewares,salon,With that spare Scandinavian look,239.0,http://d3idkbp2p2okv.cloudfront.net/images/housewares/f0501d3b-1bbb-44b1-905d-d11eb8a7fe01.jpg,,3
# b011ddc3-632f-47cb-a68a-ad83678ecfed,http://d3idkbp2p2okv.cloudfront.net/#/product/b011ddc3-632f-47cb-a68a-ad83678ecfed,Classic coat-rack,housewares,salon,All the functionality of coatracks with the style of coatracks,167.0,http://d3idkbp2p2okv.cloudfront.net/images/housewares/b011ddc3-632f-47cb-a68a-ad83678ecfed.jpg,,3
# 82f4c1ca-b0dc-4e5a-9336-caff8bf63c05,http://d3idkbp2p2okv.cloudfront.net/#/product/82f4c1ca-b0dc-4e5a-9336-caff8bf63c05,Precious Cargo Makeup Containers,beauty,grooming,"Strong reinforced plastic containers, with bright stylings.",12.0,http://d3idkbp2p2okv.cloudfront.net/images/beauty/82f4c1ca-b0dc-4e5a-9336-caff8bf63c05.jpg,F,20
# cfe46492-c19b-4a3c-a022-540c49cc63bb,http://d3idkbp2p2okv.cloudfront.net/#/product/cfe46492-c19b-4a3c-a022-540c49cc63bb,Lovely Blue Mascara,beauty,grooming,You will never look beyond this shade of blue.,29.0,http://d3idkbp2p2okv.cloudfront.net/images/beauty/cfe46492-c19b-4a3c-a022-540c49cc63bb.jpg,F,2
# e0667c61-6f47-4481-a0a0-beaf734e477a,http://d3idkbp2p2okv.cloudfront.net/#/product/e0667c61-6f47-4481-a0a0-beaf734e477a,Nail Varnish for Conquerors of Hearts,beauty,grooming,Occupy his/her heart with your talons of love!,24.0,http://d3idkbp2p2okv.cloudfront.net/images/beauty/e0667c61-6f47-4481-a0a0-beaf734e477a.jpg,F,3
# a4ea1f55-4f9e-4efa-ab32-343676b69593,http://d3idkbp2p2okv.cloudfront.net/#/product/a4ea1f55-4f9e-4efa-ab32-343676b69593,Eye Care Set - Sparkle Gloss Eyes and Lashes,beauty,grooming,Your eyes will dazzle and gloss and shine and fizz pop.,95.0,http://d3idkbp2p2okv.cloudfront.net/images/beauty/a4ea1f55-4f9e-4efa-ab32-343676b69593.jpg,F,2

# %%
# !bq load --project_id=data-talk-385706 --skip_leading_rows=1 --source_format=CSV sources.products products.csv id:STRING,url:STRING,name:STRING,category:STRING,style:STRING,description:STRING,price:FLOAT,image:STRING,gender_affinity:STRING,current_stock:INTEGER
# Out:
# Upload complete.
# Waiting on bqjob_r1c0c82ceaf53d8d9_000001890561b422_1 ... (1s) Current status: DONE

# %%
# %%bigquery --project data-talk-385706
#
# select
#   *
# from data-talk-385706.sources.products
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                      id  \
# 0  9f5d5280-76ef-43fa-af68-f0ba26a5f640
# 1  ba0c2cb6-26b8-488f-81ad-0fa52eb04940
# 2  6b81a807-d7eb-41b5-8e6e-887455775c38
# 3  5a9e66ed-32c5-461e-a4b0-a56948c3235b
# 4  3d882b22-847d-4d7f-9a74-3bd290db95c2
# 5  baae9ca1-2fd5-4161-8eb3-d0c0616e34f6
# 6  d51e4f8e-c010-4ddd-a88b-b70820806e17
# 7  da94e783-5959-4df1-bca1-6719ece02699
# 8  0c4e5ca2-93cd-4ddb-a5d3-197fa2221ead
# 9  af669fc5-d861-41dd-b6a0-30fc30519252
#
#                                                  url                 name  \
# 0  http://d3idkbp2p2okv.cloudfront.net/#/product/...                  Axe
# 1  http://d3idkbp2p2okv.cloudfront.net/#/product/...                  Axe
# 2  http://d3idkbp2p2okv.cloudfront.net/#/product/...  Canvas Everyday Bag
# 3  http://d3idkbp2p2okv.cloudfront.net/#/product/...    Black Leather Bag
# 4  http://d3idkbp2p2okv.cloudfront.net/#/product/...  Sienna Everyday Bag
# 5  http://d3idkbp2p2okv.cloudfront.net/#/product/...        Pet Accessory
# 6  http://d3idkbp2p2okv.cloudfront.net/#/product/...        Dog Accessory
# 7  http://d3idkbp2p2okv.cloudfront.net/#/product/...        Dog Accessory
# 8  http://d3idkbp2p2okv.cloudfront.net/#/product/...        Pet Accessory
# 9  http://d3idkbp2p2okv.cloudfront.net/#/product/...        Pet Accessory
#
#       category style                                    description   price  \
# 0        tools   axe            Essential axe for every craftperson   21.99
# 1        tools   axe       This axe is a must-have for your toolbox    9.99
# 2  accessories   bag  An all-around convenient bag for everyday use  118.99
# 3  accessories   bag  An all-around convenient bag for everyday use   96.99
# 4  accessories   bag  An all-around convenient bag for everyday use  114.99
# 5     outdoors   pet              Your pet will love this accessory  -11.99
# 6     outdoors   pet              Your dog will love this accessory  -43.99
# 7     outdoors   pet              Your dog will love this accessory   42.99
# 8     outdoors   pet              Your pet will love this accessory   52.99
# 9     outdoors   pet              Your pet will love this accessory   13.99
#
#                                                image gender_affinity  \
# 0  http://d3idkbp2p2okv.cloudfront.net/images/too...            None
# 1  http://d3idkbp2p2okv.cloudfront.net/images/too...            None
# 2  http://d3idkbp2p2okv.cloudfront.net/images/acc...            None
# 3  http://d3idkbp2p2okv.cloudfront.net/images/acc...            None
# 4  http://d3idkbp2p2okv.cloudfront.net/images/acc...            None
# 5  http://d3idkbp2p2okv.cloudfront.net/images/out...            None
# 6  http://d3idkbp2p2okv.cloudfront.net/images/out...            None
# 7  http://d3idkbp2p2okv.cloudfront.net/images/out...            None
# 8  http://d3idkbp2p2okv.cloudfront.net/images/out...            None
# 9  http://d3idkbp2p2okv.cloudfront.net/images/out...            None
#
#    current_stock
# 0              8
# 1             15
# 2              6
# 3              8
# 4             16
# 5             -9
# 6            -14
# 7              6
# 8              7
# 9              8

# %% [markdown]
# ## Loading interactions

# %%
# !head interactions.csv
# Out:
# ITEM_ID,USER_ID,EVENT_TYPE,TIMESTAMP,DISCOUNT
# 00096972-5f6b-44df-917b-f7d21ae5644c,5889,ProductViewed,1593390962,false
# 00096972-5f6b-44df-917b-f7d21ae5644c,5889,ProductViewed,1596444341,false
# 00096972-5f6b-44df-917b-f7d21ae5644c,782,ProductViewed,1593696050,true
# 00096972-5f6b-44df-917b-f7d21ae5644c,782,ProductViewed,1596531616,false
# 00096972-5f6b-44df-917b-f7d21ae5644c,782,ProductAdded,1593696054,true
# 00096972-5f6b-44df-917b-f7d21ae5644c,782,ProductViewed,1593307661,true
# 00096972-5f6b-44df-917b-f7d21ae5644c,782,ProductViewed,1597979938,false
# 00096972-5f6b-44df-917b-f7d21ae5644c,4369,ProductAdded,1596133790,false
# 00096972-5f6b-44df-917b-f7d21ae5644c,4369,ProductViewed,1592996323,false

# %%
# !bq load --project_id=data-talk-385706 --skip_leading_rows=1 --source_format=CSV sources.interactions interactions.csv item_id:STRING,user_id:INTEGER,event_type:STRING,timestamp:INTEGER,discount:BOOLEAN
# Out:
# Upload complete.
# Waiting on bqjob_r53a8460c3ef60e40_000001890566ab57_1 ... (4s) Current status: DONE

# %%
# %%bigquery --project data-talk-385706
#
# select
#   *
# from `data-talk-385706.sources.interactions`
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                 item_id  user_id  event_type   timestamp  \
# 0  00096972-5f6b-44df-917b-f7d21ae5644c     2884  CartViewed  1596605062
# 1  00096972-5f6b-44df-917b-f7d21ae5644c     3709  CartViewed  1597325120
# 2  00096972-5f6b-44df-917b-f7d21ae5644c      468  CartViewed  1595917345
# 3  00096972-5f6b-44df-917b-f7d21ae5644c     1752  CartViewed  1593844500
# 4  0016fde3-0910-4cc1-8ef6-90e15f271073      538  CartViewed  1594988695
# 5  0016fde3-0910-4cc1-8ef6-90e15f271073      560  CartViewed  1592643712
# 6  0016fde3-0910-4cc1-8ef6-90e15f271073     3706  CartViewed  1597180143
# 7  0016fde3-0910-4cc1-8ef6-90e15f271073     4222  CartViewed  1595632660
# 8  0016fde3-0910-4cc1-8ef6-90e15f271073     1413  CartViewed  1597888988
# 9  0016fde3-0910-4cc1-8ef6-90e15f271073     3296  CartViewed  1595913813
#
#    discount
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False

# %% [markdown]
# # Transforming data

# %% [markdown]
# ## Creating transform dataset

# %%
# !bq mk --project_id=data-talk-385706 transform
# Out:
# Dataset 'data-talk-385706:transform' successfully created.

# %% [markdown]
# ## users json extraction

# %%
# %%bigquery --project data-talk-385706
#
# create or replace table `data-talk-385706.transform.users`
# as
#
# SELECT
# id,
# username,
# email,
# first_name,
# last_name
# --addresses,
# -- ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.first_name'),'"','') AS first_name
# -- ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.last_name'),'"','') AS last_name
# ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.address1'),'"','') AS address1
# ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.address2'),'"','') AS address2
# ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.country'),'"','') AS country
# ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.city'),'"','') AS city
# ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.state'),'"','') AS state
# ,replace(JSON_EXTRACT(replace(ADDRESSES,'[',''), '$.zipcode'),'"','') AS zipcode
# ,age,
# gender,
# persona,
# discount_persona
#   FROM `data-talk-385706.sources.users`-- LIMIT 10
# ;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery --project data-talk-385706
#
# select
#   *
# from data-talk-385706.transform.users
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      id  username                       email first_name   last_name  \
# 0  1584  user1584        jo.davis@example.com         Jo       Davis
# 1  3885  user3885     amy.sanchez@example.com        Amy     Sanchez
# 2  5753  user5753      amy.garcia@example.com        Amy      Garcia
# 3  5524  user5524       amy.perez@example.com        Amy       Perez
# 4  5025  user5025      amy.bailey@example.com        Amy      Bailey
# 5  5202  user5202  amy.strickland@example.com        Amy  Strickland
# 6  1988  user1988    amy.santiago@example.com        Amy    Santiago
# 7   405   user405       amy.smith@example.com        Amy       Smith
# 8  5819  user5819      amy.foster@example.com        Amy      Foster
# 9  2393  user2393       amy.adams@example.com        Amy       Adams
#
#                            address1 address2 country                 city  \
# 0       6763 Justin River Suite 929               US           Jasonville
# 1     17166 Williams Ports Apt. 886               US        Port Josefort
# 2                 66174 Scott Haven               US          Briannafurt
# 3               34467 Johnson Mount               US          Lake Robert
# 4  46266 Miller Throughway Apt. 114               US           Karinaside
# 5         7373 Jerry Well Suite 280               US          Nataliebury
# 6                       112 Le Rest               US           New Nicole
# 7                  584 Joseph Walks               US          Johnsonfurt
# 8         556 Carol Vista Suite 468               US  Port Christinemouth
# 9                   3555 Case Forks               US         Rachaelburgh
#
#   state zipcode  age gender                         persona discount_persona
# 0    CA   91864   35      F    apparel_footwear_accessories    all_discounts
# 1    MI   48196   51      F         books_apparel_homedecor    all_discounts
# 2    VA   24087   22      F   instruments_books_electronics    all_discounts
# 3    IL   62747   34      F    apparel_footwear_accessories    all_discounts
# 4    KS   66954   55      F           floral_beauty_jewelry    all_discounts
# 5    MT   59262   64      F   electronics_outdoors_footwear    all_discounts
# 6    OH   44904   35      F    apparel_footwear_accessories    all_discounts
# 7    KS   67121   29      F  beauty_accessories_instruments    all_discounts
# 8    OH   45011   55      F         books_apparel_homedecor    all_discounts
# 9    SC   29114   33      F           floral_beauty_jewelry    all_discounts
